# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
dataset = "C:\\Users\\X474241\\OneDrive - Old Mutual\\Documents\\GitHub\\describing_distributions\\Data\\data (1).csv"
df = pd.read_csv(dataset, index_col = 0)
df.head()
# Out:
#             Lat       Lng      Area  Children  Age    Income   Marital  \
# State
# AL     34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# FL     30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# SD     43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
# MN     43.89744 -93.51479  Suburban       0.0   78  39741.49   Married
# VA     37.59894 -76.88958     Rural       1.0   22   1209.56   Widowed
#
#        Gender  ReAdmis  VitD_levels  ...  Hyperlipidemia  BackPain  Anxiety  \
# State                                ...
# AL       Male        0    19.141466  ...             0.0       1.0      1.0
# FL     Female        0    18.940352  ...             0.0       0.0      0.0
# SD     Female        0    18.057507  ...             0.0       0.0      0.0
# MN       Male        0    16.576858  ...             0.0       0.0      0.0
# VA     Female        0    17.439069  ...             1.0       0.0      0.0
#
#        Allergic_rhinitis Reflux_esophagitis  Asthma     Services Initial_days  \
# State
# AL                   1.0                  0       1   Blood Work    10.585770
# FL                   0.0                  1       0  Intravenous    15.129562
# SD                   0.0                  0       0   Blood Work     4.772177
# MN                   0.0                  1       1   Blood Work     1.714879
# VA                   1.0                  0       0      CT Scan     1.254807
#
#        TotalCharge  Additional_charges
# State
# AL     3726.702860        17939.403420
# FL     4193.190458        17612.998120
# SD     2434.234222        17505.192460
# MN     2127.830423        12993.437350
# VA     2113.073274         3716.525786
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, AL to ND
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Lat                 1000 non-null   float64
#  1   Lng                 1000 non-null   float64
#  2   Area                995 non-null    object
#  3   Children            993 non-null    float64
#  4   Age                 1000 non-null   int64
#  5   Income              1000 non-null   float64
#  6   Marital             995 non-null    object
#  7   Gender              995 non-null    object
#  8   ReAdmis             1000 non-null   int64
#  9   VitD_levels         1000 non-null   float64
#  10  Doc_visits          1000 non-null   int64
#  11  Full_meals_eaten    1000 non-null   int64
#  12  vitD_supp           1000 non-null   int64
#  13  Soft_drink          1000 non-null   int64
#  14  Initial_admin       995 non-null    object
#  15  HighBlood           1000 non-null   int64
#  16  Stroke              1000 non-null   int64
#  17  Complication_risk   995 non-null    object
#  18  Overweight          1000 non-null   int64
#  19  Arthritis           994 non-null    float64
#  20  Diabetes            994 non-null    float64
#  21  Hyperlipidemia      998 non-null    float64
#  22  BackPain            992 non-null    float64
#  23  Anxiety             998 non-null    float64
#  24  Allergic_rhinitis   994 non-null    float64
#  25  Reflux_esophagitis  1000 non-null   int64
#  26  Asthma              1000 non-null   int64
#  27  Services            995 non-null    object
#  28  Initial_days        1000 non-null   float64
#  29  TotalCharge         1000 non-null   float64
#  30  Additional_charges  1000 non-null   float64
# dtypes: float64(14), int64(11), object(6)
# memory usage: 250.0+ KB

# %%
# plotting a histogram of VitD_levels 
sns.histplot(data=df,x='VitD_levels',kde =True)
# Out:
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='VitD_levels', ylabel='Count'>

# %%
#Add a line for the mean (red)
mean = df['VitD_levels'].mean()
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(df['VitD_levels'], ax = ax, stat='probability')
ax.axvline(mean, color = 'red', label = 'mean');
ax.set_title('VitD_levels')
ax.legend();
# Out:
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Add a line for the median (green)
col = 'VitD_levels'
feature = df[col]
mean = feature.mean()
median = feature.median()
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.set_title(f'{col}')
ax.legend();
# Out:
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Add a line for for +1 std from the mean (black)
col = 'VitD_levels'
feature = df[col]
mean = feature.mean()
std = feature.std()
plus_one_std = mean + std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.set_title(f'{col}')
ax.legend()
# Out:
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Add a line for the - 1 std from the mean (black)
col = 'VitD_levels'
feature = df[col]
mean = feature.mean()
std = feature.std()
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.set_title(f'{col}')
ax.legend();
# Out:
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Highlight the range between +1 and =1 std (yellow)
col = 'VitD_levels'
feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'{col}')
ax.legend();
# Out:
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# plotting a histogram of Doc_visits
sns.histplot(data=df,x='Doc_visits',kde =True)
# Out:
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Doc_visits', ylabel='Count'>

# %%
#Add a line for the mean (red)
mean = df['Doc_visits'].mean()
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(df['Doc_visits'], ax = ax, stat='probability')
ax.axvline(mean, color = 'red', label = 'mean');
ax.set_title('Doc_visits')
ax.legend();
# Out:
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Add a line for the median (green)
col = 'Doc_visits'
feature = df[col]
mean = feature.mean()
median = feature.median()
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.set_title(f'{col}')
ax.legend();
# Out:
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Add a line for for +1 std from the mean (black)
col = 'Doc_visits'
feature = df[col]
mean = feature.mean()
std = feature.std()
plus_one_std = mean + std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.set_title(f'{col}')
ax.legend();
# Out:
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Add a line for the - 1 std from the mean (black)
col = 'Doc_visits'
feature = df[col]
mean = feature.mean()
std = feature.std()
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.set_title(f'{col}')
ax.legend();
# Out:
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Highlight the range between +1 and =1 std (yellow)
col = 'Doc_visits'
feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'{col}')
ax.legend();
# Out:
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# plotting a histogram of Doc_visits
sns.histplot(data=df,x='TotalCharge',kde =True)
# Out:
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='TotalCharge', ylabel='Count'>

# %%
#Add a line for the mean (red)
mean = df['TotalCharge'].mean()
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(df['TotalCharge'], ax = ax, stat='probability')
ax.axvline(mean, color = 'red', label = 'mean');
ax.set_title('TotalCharge')
ax.legend();
# Out:
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Add a line for the median (green)
col = 'TotalCharge'
feature = df[col]
mean = feature.mean()
median = feature.median()
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.set_title(f'{col}')
ax.legend();
# Out:
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Add a line for for +1 std from the mean (black)
col = 'TotalCharge'
feature = df[col]
mean = feature.mean()
std = feature.std()
plus_one_std = mean + std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.set_title(f'{col}')
ax.legend();
# Out:
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Add a line for the - 1 std from the mean (black)
col = 'TotalCharge'
feature = df[col]
mean = feature.mean()
std = feature.std()
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.set_title(f'{col}')
ax.legend();
# Out:
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Highlight the range between +1 and =1 std (yellow)
col = 'TotalCharge'
feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'{col}')
ax.legend();
# Out:
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\X474241\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Is it Discrete or Continuous?
# - VitD_levels is discrete
# - Doc_visits is continuous
# - TotalCharge is continious

# %% [markdown]
# # Does it have a skew? If so, which direction (+/-)
# - VitD_levels has no skew(normal)
# - Doc_visits seems to be negatively skewed
# - Totalcharge is positively skewed

# %% [markdown]
# # What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)

# %%
# VitD_levels displays Mesokurtic
kurt_VitD_levels = stats.kurtosis(df['VitD_levels'], fisher = False)
kurt_VitD_levels
# Out:
# 3.013147515833447

# %%
# Doc_visits displays Mesokurtic
kurt_Doc_visits = stats.kurtosis(df['Doc_visits'], fisher = False)
kurt_Doc_visits
# Out:
# 2.9919958083381206

# %%
# TotalCharge displays Leptokurtic
kurt_TotalCharge = stats.kurtosis(df['TotalCharge'], fisher = False)
kurt_TotalCharge
# Out:
# 3.2650077463439384
